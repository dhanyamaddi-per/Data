# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/meghn/Downloads/Author.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Author_ID    20 non-null     int64
#  1   Name         20 non-null     object
#  2   Birth_Date   20 non-null     object
#  3   Nationality  20 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 772.0+ bytes

# %%
df.describe()
# Out:
#        Author_ID
# count   20.00000
# mean    10.50000
# std      5.91608
# min      1.00000
# 25%      5.75000
# 50%     10.50000
# 75%     15.25000
# max     20.00000

# %%
df
# Out:
#     Author_ID                 Name  Birth_Date Nationality
# 0           1          Jane Austen  1775-12-16     British
# 1           2     Ernest Hemingway  1899-07-21    American
# 2           3        George Orwell  25-06-1903     British
# 3           4     Scott Fitzgerald  1896-09-24    American
# 4           5         J.K. Rowling  31-07-1965     British
# 5           6           Mark Twain  1835-11-30    American
# 6           7          Leo Tolstoy  1828-09-09     Russian
# 7           8       Virginia Woolf  1882-01-25     British
# 8           9      Gabriel Márquez  06-03-1927   Colombian
# 9          10      Charles Dickens  1812-02-07     British
# 10         11           Harper Lee  28-04-1926    American
# 11         12          Oscar Wilde  1854-10-16       Irish
# 12         13  William Shakespeare  1564-04-26     British
# 13         14          Franz Kafka  1883-07-03       Czech
# 14         15          James Joyce  1882-02-02       Irish
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.scatter(x="Nationality",                     
            y="Author_ID",                                  
               data=df)
